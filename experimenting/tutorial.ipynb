# %%
import pandas as pd 
import numpy as np

# %%
data_01 = pd.read_csv('../Tutorial/data/prices_round_0_day_-1.csv', delimiter=';')

# %%
data_02 = pd.read_csv('../Tutorial/data/prices_round_0_day_2.csv', delimiter=';')
